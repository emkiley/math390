# %% [markdown]
# ## Linear transformations
# Imagine we have 2D set of points (or any object). We can use matrices to express linear transformations for such point sets, such as reflection, rotation or scaling, see [Examples of linear transformation matrices](https://en.wikipedia.org/wiki/Linear_map). Let's implement a framework to experiment with such linear maps.

# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n=100
points=[[cos(2*pi*t/n),sin(2*pi*t/n)] for t in xrange(n)]

# %%
points
# Out:
# [[1.0, 0.0],
#  [0.99802672842827156, 0.062790519529313374],
#  [0.99211470131447788, 0.12533323356430426],
#  [0.98228725072868872, 0.1873813145857246],
#  [0.96858316112863108, 0.24868988716485479],
#  [0.95105651629515353, 0.3090169943749474],
#  [0.92977648588825146, 0.36812455268467792],
#  [0.90482705246601958, 0.42577929156507266],
#  [0.87630668004386358, 0.48175367410171532],
#  [0.84432792550201508, 0.53582679497899666],
#  [0.80901699437494745, 0.58778525229247314],
#  [0.77051324277578925, 0.63742398974868963],
#  [0.72896862742141155, 0.68454710592868862],
#  [0.68454710592868873, 0.72896862742141155],
#  [0.63742398974868975, 0.77051324277578914],
#  [0.58778525229247325, 0.80901699437494734],
#  [0.53582679497899666, 0.84432792550201508],
#  [0.48175367410171521, 0.87630668004386369],
#  [0.42577929156507266, 0.90482705246601958],
#  [0.36812455268467809, 0.92977648588825135],
#  [0.30901699437494745, 0.95105651629515353],
#  [0.24868988716485474, 0.96858316112863108],
#  [0.18738131458572471, 0.98228725072868861],
#  [0.12533323356430448, 0.99211470131447776],
#  [0.062790519529313513, 0.99802672842827156],
#  [6.123233995736766e-17, 1.0],
#  [-0.062790519529313402, 0.99802672842827156],
#  [-0.12533323356430415, 0.99211470131447788],
#  [-0.1873813145857246, 0.98228725072868872],
#  [-0.24868988716485485, 0.96858316112863108],
#  [-0.30901699437494717, 0.95105651629515364],
#  [-0.36812455268467775, 0.92977648588825146],
#  [-0.42577929156507277, 0.90482705246601947],
#  [-0.48175367410171538, 0.87630668004386347],
#  [-0.53582679497899677, 0.84432792550201496],
#  [-0.58778525229247303, 0.80901699437494745],
#  [-0.63742398974868963, 0.77051324277578925],
#  [-0.68454710592868873, 0.72896862742141155],
#  [-0.72896862742141133, 0.68454710592868884],
#  [-0.77051324277578914, 0.63742398974868986],
#  [-0.80901699437494734, 0.58778525229247325],
#  [-0.84432792550201485, 0.53582679497899699],
#  [-0.87630668004386369, 0.48175367410171521],
#  [-0.90482705246601935, 0.42577929156507288],
#  [-0.92977648588825135, 0.36812455268467814],
#  [-0.95105651629515353, 0.30901699437494751],
#  [-0.96858316112863097, 0.24868988716485524],
#  [-0.98228725072868872, 0.18738131458572455],
#  [-0.99211470131447776, 0.12533323356430454],
#  [-0.99802672842827156, 0.062790519529313582],
#  [-1.0, 1.2246467991473532e-16],
#  [-0.99802672842827156, -0.062790519529313332],
#  [-0.99211470131447788, -0.12533323356430431],
#  [-0.98228725072868861, -0.18738131458572477],
#  [-0.96858316112863119, -0.24868988716485457],
#  [-0.95105651629515364, -0.30901699437494728],
#  [-0.92977648588825146, -0.36812455268467792],
#  [-0.90482705246601969, -0.42577929156507227],
#  [-0.87630668004386347, -0.48175367410171538],
#  [-0.84432792550201519, -0.53582679497899643],
#  [-0.80901699437494778, -0.58778525229247269],
#  [-0.77051324277578925, -0.63742398974868963],
#  [-0.72896862742141177, -0.68454710592868839],
#  [-0.68454710592868862, -0.72896862742141155],
#  [-0.63742398974868963, -0.77051324277578936],
#  [-0.58778525229247325, -0.80901699437494734],
#  [-0.53582679497899632, -0.8443279255020153],
#  [-0.48175367410171532, -0.87630668004386358],
#  [-0.42577929156507216, -0.9048270524660198],
#  [-0.36812455268467775, -0.92977648588825146],
#  [-0.30901699437494756, -0.95105651629515353],
#  [-0.24868988716485443, -0.96858316112863119],
#  [-0.18738131458572463, -0.98228725072868872],
#  [-0.12533323356430462, -0.99211470131447776],
#  [-0.062790519529313193, -0.99802672842827156],
#  [-1.8369701987210297e-16, -1.0],
#  [0.062790519529312833, -0.99802672842827156],
#  [0.12533323356430423, -0.99211470131447788],
#  [0.18738131458572427, -0.98228725072868872],
#  [0.24868988716485496, -0.96858316112863108],
#  [0.30901699437494723, -0.95105651629515364],
#  [0.36812455268467748, -0.92977648588825157],
#  [0.42577929156507183, -0.90482705246601991],
#  [0.48175367410171571, -0.87630668004386336],
#  [0.53582679497899666, -0.84432792550201508],
#  [0.58778525229247292, -0.80901699437494756],
#  [0.6374239897486893, -0.77051324277578959],
#  [0.68454710592868795, -0.72896862742141222],
#  [0.72896862742141133, -0.68454710592868895],
#  [0.77051324277578936, -0.63742398974868963],
#  [0.80901699437494734, -0.58778525229247325],
#  [0.84432792550201474, -0.5358267949789971],
#  [0.87630668004386314, -0.4817536741017161],
#  [0.90482705246601935, -0.42577929156507299],
#  [0.92977648588825146, -0.36812455268467781],
#  [0.95105651629515353, -0.30901699437494762],
#  [0.96858316112863097, -0.24868988716485535],
#  [0.98228725072868872, -0.18738131458572468],
#  [0.99211470131447776, -0.12533323356430467],
#  [0.99802672842827156, -0.062790519529313263]]

# %%
array(points).T[0]
# Out:
# array([ 1.        ,  0.80901699,  0.30901699, -0.30901699, -0.80901699,
#        -1.        , -0.80901699, -0.30901699,  0.30901699,  0.80901699])

# %%
x=array(points).T[0]; y=array(points).T[1]

# %%
ifig=1;close(ifig);figure(ifig,figsize=(5,5))
plot(x,y,'rh')
# Out:
# <img src="data:image/png;base64,...">

# %%
x=array(points).T[0]; y=array(points).T[1]

# %%
x
# Out:
# array([ 1.        ,  0.80901699,  0.30901699, -0.30901699, -0.80901699,
#        -1.        , -0.80901699, -0.30901699,  0.30901699,  0.80901699])

# %%
T1 = matrix([[1,0],[0,2]])

# %%
vecs=array(points)

# %%
T1.dot(vecs[3]).A1
# Out:
# array([-0.30901699,  1.90211303])

# %%
trans_vec=T1.dot(vecs[0]).A1

# %%
trans_vec
# Out:
# array([ 1.,  2.])

# %%
len(vecs)
# Out:
# 100

# %%
# transformation:
trans_vec = []
for i in range(len(vecs)):
    this_tv = T1.dot(vecs[i]).A1
    trans_vec.append(this_tv)

# %%
xt=array(trans_vec).T[0]; yt=array(trans_vec).T[1]

# %%
ifig=1;figure(ifig)
plot(xt,yt,'o')
